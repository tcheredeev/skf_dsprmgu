# %% [markdown]
# # 3. Библиотека requests

# %% [markdown]
# ## Делаем запрос

# %% [markdown]
# Отправим наш первый запрос к ресурсу [Курсы валют ЦБ РФ в XML и JSON](https://www.cbr-xml-daily.ru/). Используем метод get() из библиотеки requests, передав ему соответствующий URL —  https://www.cbr-xml-daily.ru/daily_json.js:

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %%
print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %%
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %% [markdown]
# ### Задание 3.1

# %%
response_xlml = requests.get('https://www.cbr-xml-daily.ru/daily.xml')

# %% [markdown]
# ## Работаем с ответом

# %%
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2024-11-09T11:30:00+03:00",
#     "PreviousDate": "2024-11-08T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2024\/11\/08\/daily_json.js",
#     "Timestamp": "2024-11-10T12:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 65.0984,
#             "Previous": 64.9437
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 57.5491,
#             "Previous": 57.6898
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 127.1444,
#             "Previous": 126.4156
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 25.2558,
#             "Previous": 25.3267
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 29.3688,
#             "Previous": 29.4406
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 53.9482,
#             "Previous": 53.6288
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 17.2787,
#             "Previous": 17.0132
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 25.9746,
#             "Previous": 25.8924
#         },
#         "VND": {
#             "ID": "R01150",
#             "NumCode": "704",
#             "CharCode": "VND",
#             "Nominal": 10000,
#             "Name": "Вьетнамских донгов",
#             "Value": 40.2972,
#             "Previous": 40.3873
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 1,
#             "Name": "Гонконгский доллар",
#             "Value": 12.6074,
#             "Previous": 12.6399
#         },
#         "GEL": {
#             "ID": "R01210",
#             "NumCode": "981",
#             "CharCode": "GEL",
#             "Nominal": 1,
#             "Name": "Грузинский лари",
#             "Value": 35.7997,
#             "Previous": 35.9939
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 14.1488,
#             "Previous": 14.0658
#         },
#         "AED": {
#             "ID": "R01230",
#             "NumCode": "784",
#             "CharCode": "AED",
#             "Nominal": 1,
#             "Name": "Дирхам ОАЭ",
#             "Value": 26.6395,
#             "Previous": 26.7046
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 97.8335,
#             "Previous": 98.0726
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 105.451,
#             "Previous": 105.5679
#         },
#         "EGP": {
#             "ID": "R01240",
#             "NumCode": "818",
#             "CharCode": "EGP",
#             "Nominal": 10,
#             "Name": "Египетских фунтов",
#             "Value": 19.843,
#             "Previous": 19.8914
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 10,
#             "Name": "Индийских рупий",
#             "Value": 11.5951,
#             "Previous": 11.626
#         },
#         "IDR": {
#             "ID": "R01280",
#             "NumCode": "360",
#             "CharCode": "IDR",
#             "Nominal": 10000,
#             "Name": "Индонезийских рупий",
#             "Value": 62.0495,
#             "Previous": 61.9145
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 19.876,
#             "Previous": 19.9278
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 70.5564,
#             "Previous": 70.3786
#         },
#         "QAR": {
#             "ID": "R01355",
#             "NumCode": "634",
#             "CharCode": "QAR",
#             "Nominal": 1,
#             "Name": "Катарский риал",
#             "Value": 26.8773,
#             "Previous": 26.943
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 10,
#             "Name": "Киргизских сомов",
#             "Value": 11.3496,
#             "Previous": 11.3773
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 13.594,
#             "Previous": 13.624
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 54.5928,
#             "Previous": 54.8406
#         },
#         "NZD": {
#             "ID": "R01530",
#             "NumCode": "554",
#             "CharCode": "NZD",
#             "Nominal": 1,
#             "Name": "Новозеландский доллар",
#             "Value": 58.8958,
#             "Previous": 58.211
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 89.8099,
#             "Previous": 88.0752
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 24.387,
#             "Previous": 24.267
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 21.1862,
#             "Previous": 21.1953
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 129.6529,
#             "Previous": 129.6843
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 73.9874,
#             "Previous": 73.7111
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 91.7995,
#             "Previous": 92.0835
#         },
#         "THB": {
#             "ID": "R01675",
#             "NumCode": "764",
#             "CharCode": "THB",
#             "Nominal": 10,
#             "Name": "Таиландских батов",
#             "Value": 28.7348,
#             "Previous": 28.5402
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 28.6003,
#             "Previous": 28.6638
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 27.9524,
#             "Previous": 28.0207
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 76.3784,
#             "Previous": 76.6972
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 23.6548,
#             "Previous": 23.6569
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 41.7985,
#             "Previous": 41.4368
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 90.9677,
#             "Previous": 90.0216
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 112.2201,
#             "Previous": 111.9422
#         },
#         "RSD": {
#             "ID": "R01805F",
#             "NumCode": "941",
#             "CharCode": "RSD",
#             "Nominal": 100,
#             "Name": "Сербских динаров",
#             "Value": 90.1649,
#             "Previous": 90.074
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 56.141,
#             "Previous": 55.9976
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 69.926,
#             "Previous": 70.4798
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 63.8808,
#             "Previous": 63.4364
#         }
#     }
# }

# %%
from pprint import pprint # Импортируем функцию pprint()
import json # Импортируем модуль json
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран
# Out:
# {'Date': '2024-11-09T11:30:00+03:00',
#  'PreviousDate': '2024-11-08T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2024/11/08/daily_json.js',
#  'Timestamp': '2024-11-10T12:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 26.7046,
#                     'Value': 26.6395},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 25.3267,
#                     'Value': 25.2558},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 64.9437,
#                     'Value': 65.0984},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 57.6898,
#                     'Value': 57.5491},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 53.6288,
#                     'Value': 53.9482},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 17.0132,
#                     'Value': 17.2787},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 29.4406,
#                     'Value': 29.3688},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 70.3786,
#                     'Value': 70.5564},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 111.9422,
#                     'Value': 112.2201},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 13.624,
#                     'Value': 13.594},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 41.4368,
#                     'Value': 41.7985},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 14.0658,
#                     'Value': 14.1488},
#             'EGP': {'CharCode': 'EGP',
#                     'ID': 'R01240',
#                     'Name': 'Египетских фунтов',
#                     'Nominal': 10,
#                     'NumCode': '818',
#                     'Previous': 19.8914,
#                     'Value': 19.843},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 105.5679,
#                     'Value': 105.451},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 126.4156,
#                     'Value': 127.1444},
#             'GEL': {'CharCode': 'GEL',
#                     'ID': 'R01210',
#                     'Name': 'Грузинский лари',
#                     'Nominal': 1,
#                     'NumCode': '981',
#                     'Previous': 35.9939,
#                     'Value': 35.7997},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгский доллар',
#                     'Nominal': 1,
#                     'NumCode': '344',
#                     'Previous': 12.6399,
#                     'Value': 12.6074},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 25.8924,
#                     'Value': 25.9746},
#             'IDR': {'CharCode': 'IDR',
#                     'ID': 'R01280',
#                     'Name': 'Индонезийских рупий',
#                     'Nominal': 10000,
#                     'NumCode': '360',
#                     'Previous': 61.9145,
#                     'Value': 62.0495},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 10,
#                     'NumCode': '356',
#                     'Previous': 11.626,
#                     'Value': 11.5951},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 63.4364,
#                     'Value': 63.8808},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 10,
#                     'NumCode': '417',
#                     'Previous': 11.3773,
#                     'Value': 11.3496},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 70.4798,
#                     'Value': 69.926},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 19.9278,
#                     'Value': 19.876},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 54.8406,
#                     'Value': 54.5928},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 88.0752,
#                     'Value': 89.8099},
#             'NZD': {'CharCode': 'NZD',
#                     'ID': 'R01530',
#                     'Name': 'Новозеландский доллар',
#                     'Nominal': 1,
#                     'NumCode': '554',
#                     'Previous': 58.211,
#                     'Value': 58.8958},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 24.267,
#                     'Value': 24.387},
#             'QAR': {'CharCode': 'QAR',
#                     'ID': 'R01355',
#                     'Name': 'Катарский риал',
#                     'Nominal': 1,
#                     'NumCode': '634',
#                     'Previous': 26.943,
#                     'Value': 26.8773},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 21.1953,
#                     'Value': 21.1862},
#             'RSD': {'CharCode': 'RSD',
#                     'ID': 'R01805F',
#                     'Name': 'Сербских динаров',
#                     'Nominal': 100,
#                     'NumCode': '941',
#                     'Previous': 90.074,
#                     'Value': 90.1649},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 90.0216,
#                     'Value': 90.9677},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 73.7111,
#                     'Value': 73.9874},
#             'THB': {'CharCode': 'THB',
#                     'ID': 'R01675',
#                     'Name': 'Таиландских батов',
#                     'Nominal': 10,
#                     'NumCode': '764',
#                     'Previous': 28.5402,
#                     'Value': 28.7348},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 92.0835,
#                     'Value': 91.7995},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 28.0207,
#                     'Value': 27.9524},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 28.6638,
#                     'Value': 28.6003},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 23.6569,
#                     'Value': 23.6548},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 98.0726,
#                     'Value': 97.8335},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 76.6972,
#                     'Value': 76.3784},
#             'VND': {'CharCode': 'VND',
#                     'ID': 'R01150',
#                     'Name': 'Вьетнамских донгов',
#                     'Nominal': 10000,
#                     'NumCode': '704',
#                     'Previous': 40.3873,
#                     'Value': 40.2972},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 129.6843,
#                     'Value': 129.6529},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 55.9976,
#                     'Value': 56.141}}}

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 105.5679,
#  'Value': 105.451}

# %% [markdown]
# ### Задание 3.2

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# #  4. Парсинг сайтов

# %% [markdown]
# ## Получаем содержимое веб-страницы

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" lang="ru">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" as="font" type="font/woff2" crossorigin />
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" as="font" type="font/woff2" crossorigin />
#   <link href="/front-build/css/main.css?id=842e64708435127ee441c2e86afffea2" rel="stylesheet">
#   <link href="/front-build/css/app.css?id=92673ebe7185ebc42e29fc7294a4c65f" rel="stylesheet">
#
#
#   <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#   <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#   <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#   <link rel="manifest" href="/site.webmanifest">
#   <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#f26e40">
#   <meta name="msapplication-TileColor" content="#f26e40">
#   <meta name="theme-color" content="#ffffff">
#
#   <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021">
#
#   <meta name="yandex-verification" content="8c90b02c84ac3b72"/>
#   <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#   <!-- Google Tag Manager -->
#
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
#
#   <!-- End Google Tag Manager -->
#
#     <!-- HuggingCat -->
#         <script async src="https://huggingcat-web.pages.dev/mywidget.js?static=true"></script>
#         <script>
#             (function (c, a) {
#                 var t = (c[a] = c[a] || []);
#                 t.push(["init"]);
#             })(window, "hc");
#         </script>
#     <!-- End HuggingCat -->
#
#     <!-- Ads -->
#         <script src="/front-build/js/modules/prebid.js?id=ddf9cebd6b4c7a66be2ec26a926d5f3c"></script>
#         <script src="/front-build/js/modules/initPrebidAds.js?id=db7f979f79b0f2f3b5f3233e43842936"></script>
#
#         <script src="https://widget.sparrow.ru/js/embed.js"></script>
#     <!-- End Ads -->
#
#
#
#
#
#
#
#   <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#   <meta property="og:site_name" content="N + 1 — главное издание о науке, технике и технологиях"/>
#   <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta property="og:image" content="https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"/>
#   <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021"/>
#   <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta property="og:type" content="article"/>
#
#     <meta itemprop="datePublished" content="2021-10-11"/>
#   <!-- amp page -->
#   <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#
#   <meta itemprop="datePublished" content="2021-10-11"/>
#
#
#
#       <meta name="mediator_author" content="Илья Ферапонтов"/>
#     <meta name="author" content="Илья Ферапонтов"/>
#
#   <meta name="copyright" content=""/>
#
#       <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2021/10/11/econobel2021"
#       },
#       "headline": "Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей",
#       "description": "",
#             "image": "https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg",
#
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Илья Ферапонтов",
#                 "image": "https://minio.nplus1.ru/app-images/793327/f7199286c33e5d744656c65cc770eb5e.jpg",
#                 "url": "https://nplus1.ru/author/ilya-ferapontov"
#         },
#
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"
#       }
#     },
#     "datePublished": "2021-10-11",
#       "dateModified": "2021-10-11"
#     }
#
#
#
#     </script>
#
#
#
#
#   <meta name="twitter:card" content="summary_large_image">
#   <meta name="twitter:site" content="@nplusodin"/>
#   <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta name="twitter:image" content="https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"/>
#
#   <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="antialiased">
#
# <!-- Top.Mail.Ru counter -->
#
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
#
# <noscript><div><img src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;" alt="Top.Mail.Ru" /></div></noscript>
#
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
#   <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ"
#   height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <div id="appfront" class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray">
#   <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50"
#         data-ref-header
#         ref="headerRef">
#
#       <div id="progressBar" class="absolute bg-main-gray/5 bottom-0 left-0 top-0" style="z-index: -1"></div>
#
#   <div class="border-b border-main-gray h-full">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full"
#          data-ref-header-container
#          ref="headerContainerRef">
#
#       <button aria-label="Go" data-ref-header-menu-btn
#               ref="headerMenuBtnRef"
#               id="topMenuBtn"
#               @click="menuOpen"
#               class="w-7.5 h-7.5">
#         <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_cross_menu"></use>
#           </svg>
#         </template>
#         <template v-else>
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_burger"></use>
#           </svg>
#         </template>
#       </button>
#
#       <div>
#                   <a href="/">
#                         <img loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" height="23" width="57" alt="as">
#                       </a>
#               </div>
#
#       <a href="/search" class="w-7.5 h-7.5">
#         <svg class="w-full h-full">
#           <use xlink:href="#n1_pupa"></use>
#         </svg>
#       </a>
#     </div>
#   </div>
#
#   <nav v-if="isOpenDesktopMenu" id="navMenu" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavDesktop">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#
#
#         <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#
#         <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75"
#            href="https://offline.nplus1.ru/">N + offline</a>
#         <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75"
#            href="https://nplus.pro/">N + production</a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#         <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#
#                                     <a
#
#                                 href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75"
#               >
#                 О нас
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75"
#               >
#                 Сложность
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75"
#               >
#                 Рекламодателям
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75"
#               >
#                 Авторам
#               </a>
#
#         </div>
#
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=946">Игры</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=869">Физика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=874">Зоология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=880">Астрономия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=768">Генетика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=890">Математика</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=871">Космонавтика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=876">Археология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=775">Нейронауки</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=767">На мышах</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=771">Звук</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=772">Красота</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=824">Книжная полка</a>
#                       </div>
#
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </nav>
#
#   <nav v-if="isOpenMobileMenu" id="mobNavMenu" class="relative bg-white max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavMobile">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#                                   <a
#
#                                 href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75"
#               >
#                 О нас
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75"
#               >
#                 Сложность
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75"
#               >
#                 Рекламодателям
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75"
#               >
#                 Авторам
#               </a>
#                                                                                                                                                                 </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=946">Игры
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=869">Физика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=890">Математика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=876">Археология
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=771">Звук
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=772">Красота
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
#
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#         <div class="flex gap-x-5 overflow-x-auto">
#
#           <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
#           <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
#         </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#
#     </div>
#   </nav>
#
# </header>
#
#
#   <app-heading-nav></app-heading-nav>
#
#   <section class="mb-15 md:mb-20">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-7.5 relative"
#          data-heading-wrap>
#
#       <!--tags-->
#
#               <div class="relative flex-wrap col-span-6 md:col-span-12 lg:col-span-2 lg:row-span-3 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
#           <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#                           <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
#                 <span class="group-hover:text-main transition-colors duration-75">13:04</span>
#               </span>
#
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/news/2021/10/11">
#               <span class="group-hover:text-main transition-colors duration-75">11.10.21</span>
#             </a>
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/material/difficulty/1">
#               <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#                 <use xlink:href="#n1_star"></use>
#               </svg>
#               <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#             </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="https://nplus1.ru/search?tags=898">
#                   <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#                 </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="https://nplus1.ru/search?tags=785">
#                   <span class="group-hover:text-main transition-colors duration-75">Нобелевская премия</span>
#                 </a>
#
#           </div>
#           <div class="hidden lg:flex items-center gap-x-2">
#             <a href="https://nplus1.ru/material-print/30917" target="_blank" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22"
#                    height="30" viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"/>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"/>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"/>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"/>
#               </svg>
#             </a>
#
#             <app-copy-material
#                     link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                     type="full-2"
#             ></app-copy-material>
#           </div>
#
#           <div class="w-full flex flex-col mt-5">
#
#
#                       </div>
#
#           <div class="header-bidding-ad-container header-bidding-ad-container--left hidden lg:hidden flex-col mt-5 w-160 h-600">
#             <app-header-bidding-ad
#                 :id="898517"
#                 width="160px"
#                 height="600px"
#                 :close-button="false"
#             ></app-header-bidding-ad>
#           </div>
#         </div>
#
#       <!--dotes menu mobile-->
#       <template v-if="isMobile">
#         <button
#                 @click="openMobileDotsMenu"
#                 class="absolute flex right-5 top-5 z-30 text-main-black" >
#           <svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30" fill="none"
#                class="fill-current">
#             <path fill-rule="evenodd" clip-rule="evenodd"
#                   d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z"/>
#           </svg>
#         </button>
#
#         <div ref="mobileDotsMenuRef"
#              :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }">
#
#           <app-copy-material
#                   link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                   type="mobile"
#           ></app-copy-material>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"/>
#             </svg>
#           </button>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <rect x="0.833984" y="0.5" width="28.3333" height="39"/>
#               <line x1="5.66732" y1="10.1665" x2="24.334" y2="10.1665"/>
#               <line x1="5.66732" y1="28.8335" x2="24.334" y2="28.8335"/>
#               <line x1="5.66732" y1="19.5" x2="24.334" y2="19.5"/>
#             </svg>
#           </button>
#
#         </div>
#       </template>
#
#       <!-- main image -->
#             <!--main-->
#
#       <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
#         <div class="flex flex-col">
#
#
#           <h1 class="text-34 md:text-42 xl:text-52 break-words mb-6">
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей
#           </h1>
#
#
#
#
#             <div class="text-14 mb-5 sm:mb-12 flex flex-wrap">
#
#
#                 <span class="whitespace-nowrap">
#
#                   <a class="underline" href="/author/ilya-ferapontov">Илья Ферапонтов</a>
#                 </span>
#
#
#
#
#             </div>
#
#           <div data-lmb-0 class="mb-14">
#
#
#
#
#                                                             <BaseGalleryMain :gid="18670"></BaseGalleryMain>
#
#                      <div></div>
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a> на официальном сайте Нобелевской премии.</p></div>
#
#
#                                             <div class="block md:hidden col-span-6 mb-6">
#                             <div class="w-full" data-ref-sidebar></div>
#
#                                                                                                                                         <a
#                                             href="https://nplus1.ru/material/2024/10/28/ozon-soc"
#                                             target="_blank"
#                                             id="adv-banner-link-text"
#                                             data-adv-banner-id="8"
#                                         >
#                                             <picture>
#                                                 <source media="(min-width: 768px)" srcset="https://minio.nplus1.ru/app-images/968786/988b48e8a7667363bf66de078ae08203.png">
#
#                                                 <img
#                                                     class="w-full"
#                                                     src="https://minio.nplus1.ru/app-images/968787/2ba46fb0b05a4d2c0e7de71e5fc75b9d.png"
#                                                     loading="lazy"
#                                                     alt="Ozon — Концентрированный SOC"
#                                                 >
#                                             </picture>
#                                         </a>
#                                                                                                                         </div>
#
#
#
#
#
#
#                                                             <BaseGalleryMain :gid="1381"></BaseGalleryMain>
#
#                      <div></div>
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале <a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на бедных»</a>. В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6"><i>Сергей Кузнецов</i></p></div>
#
#
#
#
#                                       </div>
#
#
#           <div class="text-18">
#
#
#
#             <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
#
#           </div>
#
#         </div>
#       </div>
#
#       <!--right sidebar-->
#
#       <div class="block col-span-6 md:col-span-4 lg:col-span-3 row-span-3 mt-10">
#             <div class="w-full" data-ref-sidebar></div>
#
#
#                                                             <a
#                             class="hidden md:block"
#                             href="https://nplus1.ru/material/2024/10/28/ozon-soc"
#                             target="_blank"
#                             id="adv-banner-link-sidebar"
#                             data-adv-banner-id="8"
#                         >
#                             <picture>
#                                 <source media="(min-width: 768px)" srcset="https://minio.nplus1.ru/app-images/968786/988b48e8a7667363bf66de078ae08203.png">
#
#                                 <img
#                                     class="w-full"
#                                     src="https://minio.nplus1.ru/app-images/968787/2ba46fb0b05a4d2c0e7de71e5fc75b9d.png"
#                                     loading="lazy"
#                                     alt="Ozon — Концентрированный SOC"
#                                 >
#                             </picture>
#                         </a>
#
#
#                     <div class="header-bidding-ad-container header-bidding-ad-container--right hidden md:hidden flex-col mt-5 w-300 h-600">
#                         <app-header-bidding-ad
#                             :id="898516"
#                             width="300px"
#                             height="600px"
#                             :close-button="false"
#                         ></app-header-bidding-ad>
#                     </div>
#
#
#                   </div>
#     </div>
#   </section>
#
#
#       <section class="mb-9 md:mb-20">
#
#
#   <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
#
#     <!--tags-->
#
#           <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
#         <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/blog/2023/07/05">
#             <span class="group-hover:text-main transition-colors duration-75">05.07.23</span>
#           </a>
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/material/difficulty/1">
#             <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#               <use xlink:href="#n1_star"></use>
#             </svg>
#             <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#           </a>
#
#                                     <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="https://nplus1.ru/search?tags=817">
#                 <span class="group-hover:text-main transition-colors duration-75">История</span>
#               </a>
#                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="https://nplus1.ru/search?tags=898">
#                 <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#               </a>
#
#
#         </div>
#         <div class="hidden lg:flex items-center gap-x-2">
#
#
#
#
#
#
#
#
#                       <a href="https://nplus1.ru/material-print/65501" aria-label="Go" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22" height="30"
#                    viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"></rect>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"></line>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"></line>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"></line>
#               </svg>
#             </a>
#
#
#
#
#
#
#                       <app-copy-material
#                     link="https://nplus1.ru/blog/2023/07/05/his-times-his-crimes"
#                     type="full-2"
#             ></app-copy-material>
#
#         </div>
#       </div>
#
#     <!--main image  -->
#
#
#
#     <!--main-->
#
#     <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0 ">
#       <div class="flex flex-col">
#
#         <div class="text-34 md:text-42 xl:text-52 break-words">
#           «Уинстон Черчилль: его эпоха, его преступления»
#         </div>
#
#                   <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Критический взгляд на фигуру «величайшего британца в истории»</p>
#
#                   <div class="grid grid-cols-6 sm:grid-cols-7 items-center text-14 pt-1.5 sm:pt-6 mb-10 sm:mb-13 gap-y-10 gap-x-5 md:gap-x-9">
#             <div class="col-span-6 sm:col-span-3 gap-x-5 flex items-center">
#                               <a class="shrink-0 w-12 h-12" href="/author/alpina-non-fiksn">
#                   <img src="https://minio.nplus1.ru/app-images/694729/1ccc6e9960399e0551870d97fc98b306.jpg"
#                        loading="lazy"
#                        class="w-full h-full object-cover" alt="Альпина нон-фикшн">
#                 </a>
#                             <a class="text-14 flex flex-col" href="/author/alpina-non-fiksn">
#                 <span class="mb-0.5">
#
#                                     Альпина нон-фикшн
#                 </span>
#                 <span class="font-spectral text-main-gray">Научно-популярное издательство</span>
#               </a>
#             </div>
#             <div class="col-span-6 sm:col-span-3 lg:col-start-5">
#               <p class="font-spectral text-main-gray">Мнение редакции может не совпадать с&nbsp;мнением автора</p>
#             </div>
#           </div>
#
#         <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
#
#             <a class="underline whitespace-nowrap"
#                href="/author/alpina-non-fiksn">Альпина нон-фикшн</a>
#
#
#                   </div>
#
#         <div class="n1_material text-18" id="read-next-2">
#           <p class="mb-6">Уинстон Черчилль известен прежде всего как политик и полководец, возглавивший Великобританию в войне с нацизмом. Однако многим он также запомнился как сторонник империализма и воплощение правящего класса, который боролся с рабочими и подавлял всякое инакомыслие. В книге «Уинстон Черчилль: его эпоха, его преступления» (издательство «Альпина нон-фикшн»), переведенной на русский язык Максимом Коробовым, историк Тарик Али рассказывает о неприглядных эпизодах политической карьеры Черчилля, в том числе военных ошибках, допущенных в ходе Первой мировой войны, борьбе с ирландскими националистами и голоде в Бенгалии. Предлагаем вам ознакомиться с фрагментом, посвященным тому, как действия правительства Великобритании привели к крупнейшей забастовке в истории британского рабочего движения.</p>
#         </div>
#
#         <div class="mt-5 md:mt-6 mb-5">
#           <a class="inline-flex justify-center bg-main w-full py-4"
#              href="https://nplus1.ru/blog/2023/07/05/his-times-his-crimes">
#             <span class="text-white text-22 md:text-24">Читать дальше</span>
#           </a>
#         </div>
#
#       </div>
#     </div>
#
#   </div>
# </section>
#
#
#
#
#   <div class="mb-5 w-full overflow-hidden">
#     <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
#   <template v-slot:default="slotProps">
#
#
#   </template>
# </app-material-slider-carousel>
#   </div>
#
#   <div class="exchange-ad-container mb-5">
#         <app-exchange-ad
#             script-url="/front-build/js/modules/initExchangeAds.js?id=48b7ac745d78ed266ed6e7ad2b3242bc"
#             data-key="545b0632c32e67738ab0b6219c3153a6"
#         ></app-exchange-ad>
#   </div>
#
#   <app-typo-modal :width="constContainer" material-id="30917"></app-typo-modal>
#
#
#
#
#   <footer class="mt-auto relative">
#   <app-cookie></app-cookie>
#
#   <div class="bg-main-black pb-15 sm:py-10 md:py-12 xl:py-15">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 sm:gap-x-9">
#       <div class="order-1 col-span-6 sm:col-span-3 lg:col-span-2 mb-12 sm:mb-10">
#         <div>
#           <svg class="n1_footer_logo" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 148 60" fill="none">
#             <path d="M0 60V0H11.6065L36.9417 37.8V0H49.5723V60H37.8804L12.5339 22.2V60H0Z" fill="#F9F9F9"></path>
#             <path d="M75.0234 11.144H85.9471V24.8583H98.9191V35.0583H85.9471V48.8583H75.0234V35.0583H62.1367V24.8583H75.0234V11.144Z"
#                   fill="#F9F9F9"></path>
#             <path d="M136.304 49.5429H147.999V60H111.473V49.5429H124.103V21.8571C123.118 22.0352 122.118 22.1213 121.116 22.1143H111.643V11.9143H119.751C122.823 11.9143 124.274 9.08572 124.274 5.82858V0H136.307L136.304 49.5429Z"
#                   fill="#F9F9F9"></path>
#           </svg>
#         </div>
#       </div>
#       <ul class="order-2 sm:order-3 col-span-6 sm:col-span-3 lg:col-span-2 row-span-2 text-26 sm:text-16 text-light-gray font-spectral font-light mb-10 lg:mb-0 gap-y-1.5 sm:gap-y-4 flex flex-col">
#                               <li>
#               <a target="_blank" href="https://nplus1.ru/about"
#                  class="transition-colors duration-75 hover:text-main">О нас</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/difficult"
#                  class="transition-colors duration-75 hover:text-main">Сложность</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/adv"
#                  class="transition-colors duration-75 hover:text-main">Рекламодателям</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/blog/2022/04/01/samotek"
#                  class="transition-colors duration-75 hover:text-main">Авторам</a>
#             </li>
#                                                                                                                                     </ul>
#       <div class="order-2 col-span-6 sm:col-span-9 lg:col-span-10 mb-10">
#         <h4 class="text-gray-2 text-18 md:text-20 lg:text-26 col-span-10 lg:leading-28">© 2024 N + 1 Интернет-издание / Свидетельство о регистрации СМИ Эл № ФС77-67614</h4>
#       </div>
#       <div class="order-4 col-span-6 sm:col-span-9 lg:col-span-5 lg:row-span-2 mb-10 lg:mb-0">
#         <div class="text-gray-2 text-16"><p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N&nbsp;+&nbsp;1.</p>
# <p>Все аудиовизуальные произведения являются собственностью своих авторов и&nbsp;правообладателей и&nbsp;используются только в&nbsp;образовательных и&nbsp;информационных целях.</p><p>Если вы&nbsp;являетесь собственником того или иного произведения и&nbsp;не&nbsp;согласны с&nbsp;его размещением на&nbsp;нашем сайте, пожалуйста, напишите на&nbsp;<a href="/cdn-cgi/l/email-protection#ed8381ad839d81989edcc39f98"><span class="__cf_email__" data-cfemail="f29c9eb29c829e8781c3dc8087">[email&#160;protected]</span></a></p>
# <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
# <p>Связь с редакцией: <a href="/cdn-cgi/l/email-protection#94fdfaf2fbd4fae4f8e1e7a5bae6e1"><span class="__cf_email__" data-cfemail="036a6d656c436d736f7670322d7176">[email&#160;protected]</span></a></p></div>
#       </div>
#       <div class="order-5 col-span-6 sm:col-span-9 sm:col-start-4 lg:col-span-5 text-gray-2 text-16 leading-none flex flex-col">
#
#
#
#
#
#
#
#
#         <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic"
#            href="/personal-data-policy">Политика
#           обработки
#           персональных данных пользователей сайта
#         </a>
#
#       </div>
# ...
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
#
# </footer>
# </div>
#
#
# <svg id="n1_star" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      width="16" height="16"
#      viewBox="3 3 16 16" fill="none">
#   <path d="M11 5V17"/>
#   <path d="M6.75781 6.75781L15.2431 15.2431"/>
#   <path d="M17 11L5 11"/>
#   <path d="M15.2422 6.75781L6.75691 15.2431"/>
# </svg>
# <svg id="n1_person" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 50 50" fill="none">
#   <circle cx="25" cy="25" r="24.5"/>
#   <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z"
#         stroke-miterlimit="10"/>
# </svg>
# <svg id="n1_tg" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <path d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"
#         class="fill-current"/>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
# </svg>
# <svg id="n1_vk" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_ok" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_tw" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_infinity" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink" width="64px" height="64px" viewBox="0 0 100 100"
#      preserveAspectRatio="xMidYMid">
#   <path fill="none" stroke="#ffffff" stroke-width="5" stroke-dasharray="146.25568908691406 110.33323913574219"
#         d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z"
#         stroke-linecap="round" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1.3157894736842106s" keyTimes="0;1"
#              values="0;256.58892822265625"></animate>
#   </path>
# </svg>
# <svg id="n1_cross" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 14 14"
#      fill="none">
#   <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"/>
#   <path d="M13 1L1 13" stroke="#F9F9F9"/>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#   <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#         fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 61 61">
#   <path class="fill-current" fill-rule="evenodd" clip-rule="evenodd"
#         d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z"/>
#   <path class="fill-current"
#         d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"/>
# </svg>
# <svg id="n1_circle_arrow" style="display:block;width:0;height:0" class="stroke-current"
#      xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30" fill="none">
#   <rect x="29.5" y="29.5" width="29" height="29" rx="14.5" transform="rotate(-180 29.5 29.5)"/>
#   <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"/>
# </svg>
# <svg id="n1_circle_arrow_solid" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 30 30" fill="none">
#   <mask id="path-1-inside-1_2694_77554">
#     <path fill-rule="evenodd" clip-rule="evenodd"
#           d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"/>
#   </mask>
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"
#         fill="#fff"/>
#   <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z"
#         fill="#fff" mask="url(#path-1-inside-1_2694_77554)"/>
# </svg>
# <svg id="n1_play" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
#   <path d="M18 35V15L36 25L18 35Z" class="stroke-current"/>
# </svg>
# <svg id="n1_pupa" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 23"
#      fill="none">
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z"
#         fill="#32363A"/>
# </svg>
# <svg id="n1_burger" style="display:block;width:0;height:0;" viewBox="0 0 30 30" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <line y1="6.5" x2="30" y2="6.5" stroke="#32363A"/>
#   <line y1="23.5" x2="30" y2="23.5" stroke="#32363A"/>
#   <line y1="15" x2="30" y2="15" stroke="#32363A"/>
# </svg>
# <svg id="n1_cross_menu" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30"
#      fill="none">
#   <path d="M4 4L26 26" stroke="#32363A"/>
#   <path d="M26 4L4 26" stroke="#32363A"/>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" xmlns="http://www.w3.org/2000/svg"
#      version="1.1" viewBox="0 0 752 752">
#   <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"/>
# </svg>
# <svg id="n1_specials_star"
#   style="display:block;width:0;height:0;fill:none;stroke:white"
#   xmlns="http://www.w3.org/2000/svg"
#   version="1.1" viewBox="0 0 16 16">
#   <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"/>
# </svg>
#
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=dd5e25d7814af92b9161a324a2c82337"></script>
#
#
#
#
#   <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript" >
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
#   <div>
#     <img src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;" alt="" />
#     <img src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" />
#   </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
#
#
#   <script>window.yaContextCb = window.yaContextCb || []</script>
#   <script src="https://yandex.ru/ads/system/context.js" async></script>
#
#
#
#
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
#
#
#
#
# </body>
# </html>

# %% [markdown]
# # 5. Библиотека BeautifulSoup

# %% [markdown]
# ## Извлекаем данные

# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ---
# **NOTE**
#
# Если при запросе к сайту, а затем при его разборе с помощью BeautifulSoup в тексте страницы не находится нужный тег, попробуйте вывести на печать пару тысяч символов текста страницы. Если там обнаружится нечто похожее на капчу, возможно, сайт посчитал вас роботом и отказывается выдавать содержимое. Чтобы получить его, попробуйте «притвориться» браузером при запросе из скрипта
#
# requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
#
# User-Agent своего браузера можно узнать по этой [ссылке](http://n5m.ru/usagent.html).
#
#
# ---

# %%
# Применяем метод find() к объекту и выводим результат на экран
print(page.find('h1').text)
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ### Задание 5.4

# %% [markdown]
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок первого уровня для статей на Wikipedia.
#
# Функция wiki_header принимает один аргумент - url.

# %%
import requests
from bs4 import BeautifulSoup

def wiki_header(url):
    selector = '#firstHeading > span'  # Селектор заголовка
    response = requests.get(url)
    page = BeautifulSoup(response.text, 'html.parser')
    return page.select(selector)[0].text

# %%
print(wiki_header('https://en.wikipedia.org/wiki/Operating_system'))
'Operating system'
# Out:
# Operating system
# 'Operating system'

# %% [markdown]
# ## Неуникальные теги: извлекаем текст и дату публикации статьи

# %%
print(page.find('div', class_='n1_material text-18').text) # Выводим содержимое атрибута text тега div класса n1_material text-18
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %%
# Выводим на экран содержимое атрибута text тега a с классом "relative"
print(page.find('a', class_= "relative").text)
# Out:
# 11.10.21

# %% [markdown]
# ## Сбор нескольких элементов: собираем все ссылки на странице

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 948

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['Magik', 'Magma', 'Maple', 'MAPPER', 'MARK-IV', 'Mary', 'MATLAB', 'MASM Microsoft Assembly x86', 'MATH-MATIC', 'Maude system']

# %%
print([link.text for link in links[0:10]]) # Выводим ссылки с 1 по 9 включительно
# Out:
# ['Jump to content', 'Main page', 'Contents', 'Current events', 'Random article', 'About Wikipedia', 'Contact us', 'Help', 'Learn to edit', 'Community portal']

# %% [markdown]
# # 6. Работа с API

# %% [markdown]
# Рассмотрим на примере социальной сети ВКонтакте особенности API, характерные для более крупных сайтов.

# %% [markdown]
# ## Ключ авторизации

# %% [markdown]
# - Зайдите на [страницу](https://dev.vk.com/ru/admin/create-app), чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название, тип и категорию можно не менять
# - Подтвердив создание приложения на сайте в приложении ВКонтакте или по СМС, выберите на панели слева раздел **Разработка** и откройте **Ключи доступа**. Нужный нам токен лежит в поле **Сервисный ключ**:

# %%
from dotenv import load_dotenv
import os

load_dotenv('data/.env')
VKONTAKTE_SERVICED_API_KEY = os.getenv('VKONTAKTE_SERVICED_API_KEY')

# %% [markdown]
# ## Запрос к API из кода

# %%
import requests # Импортируем модуль requests
token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': VKONTAKTE_SERVICED_API_KEY, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %% [markdown]
# ### Задание 6.1

# %% [markdown]
# Мы вывели на экран дату рождения пользователя. Напишите строку кода, которая выведет на экран имя пользователя:

# %%
user = response.json()['response'][0]
print(user['first_name'])

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': VKONTAKTE_SERVICED_API_KEY, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %% [markdown]
# ### Задание 6.2

# %% [markdown]
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.

# %%
import requests
from pprint import pprint

ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': VKONTAKTE_SERVICED_API_KEY, 'lang': 'ru'}
users = requests.get(url, params=params).json()['response']
pprint(users)

genders = [0, 0, 0]

for user in users:
    genders[user['sex']] += 1
    pass

fem_and_male = genders[1] + genders[2]
print(genders[1]  / fem_and_male)
# Out:
# [{'can_access_closed': True,
#   'first_name': 'Павел',
#   'id': 1,
#   'is_closed': False,
#   'last_name': 'Дуров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Александра',
#   'id': 2,
#   'is_closed': True,
#   'last_name': 'Владимирова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 3,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 4,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Илья',
#   'id': 5,
#   'is_closed': False,
#   'last_name': 'Перекопский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Николай',
#   'id': 6,
#   'is_closed': False,
#   'last_name': 'Дуров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 7,
#   'is_closed': True,
#   'last_name': 'Кобылянский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Аки',
#   'id': 8,
#   'is_closed': False,
#   'last_name': 'Сепиашвили',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Настя',
#   'id': 9,
#   'is_closed': True,
#   'last_name': 'Васильева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Александр',
#   'id': 10,
#   'is_closed': True,
#   'last_name': 'Кузнецов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 11,
#   'is_closed': False,
#   'last_name': 'Петров',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 12,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 13,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 14,
#   'is_closed': False,
#   'last_name': 'Городецкий',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 15,
#   'is_closed': False,
#   'last_name': 'Васильков',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Виктория',
#   'id': 16,
#   'is_closed': True,
#   'last_name': 'Беспалова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Александр',
#   'id': 17,
#   'is_closed': False,
#   'last_name': 'Беспалов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Simon',
#   'id': 18,
#   'is_closed': False,
#   'last_name': 'Krechmer',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Светочек',
#   'id': 19,
#   'is_closed': False,
#   'last_name': 'Аленький',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Илья',
#   'id': 20,
#   'is_closed': True,
#   'last_name': 'Турпиашвили',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 21,
#   'is_closed': False,
#   'last_name': 'Равдоникас',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Семен',
#   'id': 22,
#   'is_closed': False,
#   'last_name': 'Воронин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 23,
#   'is_closed': False,
#   'last_name': 'Столбовский',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Рамми',
#   'id': 24,
#   'is_closed': True,
#   'last_name': 'Цицуашвили',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 25,
#   'is_closed': True,
#   'last_name': 'Ведущенко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 26,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 27,
#   'is_closed': False,
#   'last_name': 'Семиколенова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 28,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 29,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 30,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 31,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 32,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 33,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Татьяна',
#   'id': 34,
#   'is_closed': True,
#   'last_name': 'Плуталова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 35,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Иван',
#   'id': 36,
#   'is_closed': True,
#   'last_name': 'Смирнов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Михаил',
#   'id': 37,
#   'is_closed': True,
#   'last_name': 'Казекин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 38,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'David',
#   'id': 39,
#   'is_closed': False,
#   'last_name': 'Mirelli',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Олег',
#   'id': 40,
#   'is_closed': False,
#   'last_name': 'Чередников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Владислав',
#   'id': 41,
#   'is_closed': False,
#   'last_name': 'Миллер',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 42,
#   'is_closed': False,
#   'last_name': 'Маркин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 43,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Тамара',
#   'id': 44,
#   'is_closed': False,
#   'last_name': 'Мирилашвили',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 45,
#   'is_closed': False,
#   'last_name': 'Сергей',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 46,
#   'is_closed': False,
#   'last_name': 'Лесохин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Габриел',
#   'id': 47,
#   'is_closed': False,
#   'last_name': 'Шалел',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Миша',
#   'id': 48,
#   'is_closed': False,
#   'last_name': 'Мельников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Бот',
#   'id': 49,
#   'is_closed': False,
#   'last_name': 'Мороз',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Снегурочка',
#   'id': 50,
#   'is_closed': False,
#   'last_name': 'Морозова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 51,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 52,
#   'is_closed': False,
#   'last_name': 'Вознесенский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 53,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 54,
#   'is_closed': False,
#   'last_name': 'Фуртикова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 55,
#   'is_closed': True,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 56,
#   'is_closed': False,
#   'last_name': 'Чернышев',
#   'sex': 2},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'Сергей',
#   'id': 57,
#   'is_closed': True,
#   'last_name': 'Владимиров',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Александр',
#   'id': 58,
#   'is_closed': False,
#   'last_name': 'Ковалев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 59,
#   'is_closed': False,
#   'last_name': 'Желудкова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Даниэль',
#   'id': 60,
#   'is_closed': True,
#   'last_name': 'Розенберг',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Григорий',
#   'id': 61,
#   'is_closed': False,
#   'last_name': 'Конрадт',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 62,
#   'is_closed': False,
#   'last_name': 'Ланина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Никита',
#   'id': 63,
#   'is_closed': True,
#   'last_name': 'Поликарпов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 64,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Mikhail',
#   'id': 65,
#   'is_closed': False,
#   'last_name': 'Torline',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 66,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 67,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Вика',
#   'id': 68,
#   'is_closed': False,
#   'last_name': 'Мирилашвили',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Avi',
#   'id': 69,
#   'is_closed': True,
#   'last_name': 'Shalel',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Митя',
#   'id': 70,
#   'is_closed': False,
#   'last_name': 'Миронов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Людмила',
#   'id': 71,
#   'is_closed': True,
#   'last_name': 'Романченко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 72,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Надежда',
#   'id': 73,
#   'is_closed': True,
#   'last_name': 'Лебедева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Наташа',
#   'id': 74,
#   'is_closed': True,
#   'last_name': 'Филимонова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 75,
#   'is_closed': False,
#   'last_name': 'Копылова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'David',
#   'id': 76,
#   'is_closed': False,
#   'last_name': 'Biniaurischwili',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 77,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Olivia',
#   'id': 78,
#   'is_closed': True,
#   'last_name': 'Isv',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Давид',
#   'id': 79,
#   'is_closed': False,
#   'last_name': 'Спектер',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 80,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Влад',
#   'id': 81,
#   'is_closed': False,
#   'last_name': 'Куценко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Tami',
#   'id': 82,
#   'is_closed': False,
#   'last_name': 'Shalel',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Дмитрий',
#   'id': 83,
#   'is_closed': False,
#   'last_name': 'Тихомиров',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Фёдор',
#   'id': 84,
#   'is_closed': False,
#   'last_name': 'Медведев',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Mikhail',
#   'id': 85,
#   'is_closed': True,
#   'last_name': 'Gennadevich',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Никита',
#   'id': 86,
#   'is_closed': True,
#   'last_name': 'Пиастро',
#   'sex': 2},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 87,
#   'is_closed': True,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Полина',
#   'id': 88,
#   'is_closed': False,
#   'last_name': 'Олейник',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 89,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Малина',
#   'id': 90,
#   'is_closed': False,
#   'last_name': 'Baci',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дарья',
#   'id': 91,
#   'is_closed': False,
#   'last_name': 'Белинская',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Екатерина',
#   'id': 92,
#   'is_closed': True,
#   'last_name': 'Тихонова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 93,
#   'is_closed': False,
#   'last_name': 'Забоева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 94,
#   'is_closed': False,
#   'last_name': 'Теплова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 95,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 96,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 97,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 98,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Наталья',
#   'id': 99,
#   'is_closed': True,
#   'last_name': 'Брагина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'ВКонтакте',
#   'id': 100,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Администратор',
#   'id': 101,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 102,
#   'is_closed': False,
#   'last_name': 'Тенева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 103,
#   'is_closed': False,
#   'last_name': 'Романцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 104,
#   'is_closed': False,
#   'last_name': 'Ребикова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Roman',
#   'id': 105,
#   'is_closed': False,
#   'last_name': 'Ponomarenko',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Спотти',
#   'id': 106,
#   'is_closed': False,
#   'last_name': 'Космический',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Администрация',
#   'id': 107,
#   'is_closed': True,
#   'last_name': 'Б.',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Диана',
#   'id': 108,
#   'is_closed': True,
#   'last_name': 'Курбатова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 109,
#   'is_closed': False,
#   'last_name': 'Горюнова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Администрация',
#   'id': 110,
#   'is_closed': True,
#   'last_name': 'В.',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 111,
#   'is_closed': False,
#   'last_name': 'Лаврова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Евгения',
#   'id': 112,
#   'is_closed': True,
#   'last_name': 'Алексеева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Владислав',
#   'id': 113,
#   'is_closed': False,
#   'last_name': 'Умнов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 114,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 115,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 116,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Антон',
#   'id': 117,
#   'is_closed': False,
#   'last_name': 'Краснов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 118,
#   'is_closed': True,
#   'last_name': 'Никулина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 119,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 120,
#   'is_closed': False,
#   'last_name': 'Соколова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Надежда',
#   'id': 121,
#   'is_closed': False,
#   'last_name': 'Сторчевая',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Надежда',
#   'id': 122,
#   'is_closed': True,
#   'last_name': 'Игошина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 123,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Екатерина',
#   'id': 124,
#   'is_closed': True,
#   'last_name': 'Горбунова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 125,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 126,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 127,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 128,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 129,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 130,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Шурикен',
#   'id': 131,
#   'is_closed': True,
#   'last_name': 'Картошкин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 132,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Николай',
#   'id': 133,
#   'is_closed': False,
#   'last_name': 'Харчев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Илико',
#   'id': 134,
#   'is_closed': False,
#   'last_name': 'Шаптай',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Мария',
#   'id': 135,
#   'is_closed': False,
#   'last_name': 'Филатова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 136,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 137,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 138,
#   'is_closed': False,
#   'last_name': 'Рощин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Роман',
#   'id': 139,
#   'is_closed': False,
#   'last_name': 'Чистяков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 140,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 141,
#   'is_closed': True,
#   'last_name': 'Михайлов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 142,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Машечка',
#   'id': 143,
#   'is_closed': False,
#   'last_name': 'Зайцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Олег',
#   'id': 144,
#   'is_closed': False,
#   'last_name': 'Зинкевич',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Константин',
#   'id': 145,
#   'is_closed': False,
#   'last_name': 'Теплов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Александра',
#   'id': 146,
#   'is_closed': False,
#   'last_name': 'Муромцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 147,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Артём',
#   'id': 148,
#   'is_closed': False,
#   'last_name': 'Абанин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 149,
#   'is_closed': False,
#   'last_name': 'Лобакин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Луиза',
#   'id': 150,
#   'is_closed': False,
#   'last_name': 'Левиева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Леонид',
#   'id': 151,
#   'is_closed': False,
#   'last_name': 'Добронов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Илара',
#   'id': 152,
#   'is_closed': True,
#   'last_name': 'Юнаева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 153,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Елисей',
#   'id': 154,
#   'is_closed': True,
#   'last_name': 'Замахов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Dennis',
#   'id': 155,
#   'is_closed': False,
#   'last_name': 'Yurlov',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 156,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 157,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Владислав',
#   'id': 158,
#   'is_closed': False,
#   'last_name': 'Гатилов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 159,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Васильев',
#   'id': 160,
#   'is_closed': True,
#   'last_name': 'Сергеевич',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Валентина',
#   'id': 161,
#   'is_closed': False,
#   'last_name': 'Савосина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Александра',
#   'id': 162,
#   'is_closed': False,
#   'last_name': 'Аленичева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 163,
#   'is_closed': True,
#   'last_name': 'Романько',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 164,
#   'is_closed': True,
#   'last_name': 'Ткаченко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 165,
#   'is_closed': False,
#   'last_name': 'Романько',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 166,
#   'is_closed': False,
#   'last_name': 'Коменденко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Демид',
#   'id': 167,
#   'is_closed': False,
#   'last_name': 'Кириленко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Вероника',
#   'id': 168,
#   'is_closed': False,
#   'last_name': 'Кириленко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 169,
#   'is_closed': False,
#   'last_name': 'Чистоклетова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Богдан',
#   'id': 170,
#   'is_closed': False,
#   'last_name': 'Жидков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 171,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 172,
#   'is_closed': True,
#   'last_name': 'Городецкий',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 173,
#   'is_closed': False,
#   'last_name': 'Чепурная',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 174,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 175,
#   'is_closed': False,
#   'last_name': 'Захаренков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 176,
#   'is_closed': False,
#   'last_name': 'Смирнов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 177,
#   'is_closed': False,
#   'last_name': 'Абраменко',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Марья',
#   'id': 178,
#   'is_closed': True,
#   'last_name': 'Безносова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 179,
#   'is_closed': True,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 180,
#   'is_closed': False,
#   'last_name': 'Корнев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 181,
#   'is_closed': False,
#   'last_name': 'Матвеев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Николай',
#   'id': 182,
#   'is_closed': False,
#   'last_name': 'Андреев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 183,
#   'is_closed': False,
#   'last_name': 'Кретова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 184,
#   'is_closed': False,
#   'last_name': 'Владимирова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Вадим',
#   'id': 185,
#   'is_closed': True,
#   'last_name': 'Рудковский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 186,
#   'is_closed': False,
#   'last_name': 'Савинкина-Титова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Сергей',
#   'id': 187,
#   'is_closed': False,
#   'last_name': 'Воскресенкий',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Евгений',
#   'id': 188,
#   'is_closed': True,
#   'last_name': 'Лыков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Вероника',
#   'id': 189,
#   'is_closed': False,
#   'last_name': 'Лежнева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Вадим',
#   'id': 190,
#   'is_closed': False,
#   'last_name': 'Колосов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Гена',
#   'id': 191,
#   'is_closed': False,
#   'last_name': 'Загальский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 192,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 193,
#   'is_closed': False,
#   'last_name': 'Кораблев-Дайсон',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 194,
#   'is_closed': True,
#   'last_name': 'Гребнев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 195,
#   'is_closed': False,
#   'last_name': 'Келим',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 196,
#   'is_closed': False,
#   'last_name': 'Караваева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Дарья',
#   'id': 197,
#   'is_closed': True,
#   'last_name': 'Бондаренко',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Вальтер',
#   'id': 198,
#   'is_closed': True,
#   'last_name': 'Киршнер',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 199,
#   'is_closed': True,
#   'last_name': 'Жигалова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 200,
#   'is_closed': False,
#   'last_name': 'Стрельников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Игнатий',
#   'id': 201,
#   'is_closed': False,
#   'last_name': 'Дьяков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Максим',
#   'id': 202,
#   'is_closed': False,
#   'last_name': 'Ластовка',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Зоя',
#   'id': 203,
#   'is_closed': False,
#   'last_name': 'Барабанова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 204,
#   'is_closed': False,
#   'last_name': 'Скрябина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ирина',
#   'id': 205,
#   'is_closed': True,
#   'last_name': 'Ямщикова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 206,
#   'is_closed': False,
#   'last_name': 'Скрелин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Yulia',
#   'id': 207,
#   'is_closed': False,
#   'last_name': 'Bekmukhamedova',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Гена',
#   'id': 208,
#   'is_closed': True,
#   'last_name': 'Зарохин',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 209,
#   'is_closed': True,
#   'last_name': 'On',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Аня',
#   'id': 210,
#   'is_closed': False,
#   'last_name': 'Дормидонтова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 211,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Алёна',
#   'id': 212,
#   'is_closed': False,
#   'last_name': 'Фёдорова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Максим',
#   'id': 213,
#   'is_closed': True,
#   'last_name': 'Казанский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 214,
#   'is_closed': False,
#   'last_name': 'Зелёный',
#   'sex': 2},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'Екатерина',
#   'id': 215,
#   'is_closed': True,
#   'last_name': 'Мерзлякова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 216,
#   'is_closed': False,
#   'last_name': 'Мирных',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Alexander',
#   'id': 217,
#   'is_closed': False,
#   'last_name': 'Nasyrov',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Oksana',
#   'id': 218,
#   'is_closed': False,
#   'last_name': 'Zotova',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Роман',
#   'id': 219,
#   'is_closed': False,
#   'last_name': 'Акамёлков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 220,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Наталья',
#   'id': 221,
#   'is_closed': False,
#   'last_name': 'Курчакова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 222,
#   'is_closed': True,
#   'last_name': 'Ступина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Инга',
#   'id': 223,
#   'is_closed': False,
#   'last_name': 'Гладущик',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ирина',
#   'id': 224,
#   'is_closed': True,
#   'last_name': 'Кирсанова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 225,
#   'is_closed': False,
#   'last_name': 'Петропавловская',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Антон',
#   'id': 226,
#   'is_closed': True,
#   'last_name': 'Нестеров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Ася',
#   'id': 227,
#   'is_closed': True,
#   'last_name': 'Лазо',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Дима',
#   'id': 228,
#   'is_closed': True,
#   'last_name': 'Мартиросов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Гумер',
#   'id': 229,
#   'is_closed': True,
#   'last_name': 'Исаев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Олеся',
#   'id': 230,
#   'is_closed': False,
#   'last_name': 'Дигина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 231,
#   'is_closed': False,
#   'last_name': 'Бычков',
#   'sex': 2},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 232,
#   'is_closed': True,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Варя',
#   'id': 233,
#   'is_closed': False,
#   'last_name': 'Баранова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Julia',
#   'id': 234,
#   'is_closed': True,
#   'last_name': 'G-T',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Фредерик',
#   'id': 235,
#   'is_closed': False,
#   'last_name': 'Булгаков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Александра',
#   'id': 236,
#   'is_closed': False,
#   'last_name': 'Насекина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 237,
#   'is_closed': True,
#   'last_name': 'Журавлёв',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Татьяна',
#   'id': 238,
#   'is_closed': True,
#   'last_name': 'Тимофеева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 239,
#   'is_closed': True,
#   'last_name': 'Степанова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Влад',
#   'id': 240,
#   'is_closed': False,
#   'last_name': 'Коробейников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Наташа',
#   'id': 241,
#   'is_closed': False,
#   'last_name': 'Власова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 242,
#   'is_closed': False,
#   'last_name': 'Ежиков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 243,
#   'is_closed': False,
#   'last_name': 'Лапанович',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 244,
#   'is_closed': False,
#   'last_name': 'Колдунова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Zhenechka',
#   'id': 245,
#   'is_closed': False,
#   'last_name': 'Pimenofffffff',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 246,
#   'is_closed': True,
#   'last_name': 'Попов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 247,
#   'is_closed': False,
#   'last_name': 'Гордеева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 248,
#   'is_closed': False,
#   'last_name': 'Рейнгольд',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 249,
#   'is_closed': False,
#   'last_name': 'Карпова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 250,
#   'is_closed': False,
#   'last_name': 'Бабаин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 251,
#   'is_closed': False,
#   'last_name': 'Чудотворов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 252,
#   'is_closed': False,
#   'last_name': 'Микушев',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Karina',
#   'id': 253,
#   'is_closed': True,
#   'last_name': 'Mutlu',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Ася',
#   'id': 254,
#   'is_closed': True,
#   'last_name': 'Щёголь',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 255,
#   'is_closed': False,
#   'last_name': 'Уласень',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Ксения',
#   'id': 256,
#   'is_closed': True,
#   'last_name': 'Тинсли',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Саша',
#   'id': 257,
#   'is_closed': False,
#   'last_name': 'Дроздовский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 258,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Катерина',
#   'id': 259,
#   'is_closed': True,
#   'last_name': 'Албу',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 260,
#   'is_closed': False,
#   'last_name': 'Графова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Nothing',
#   'id': 261,
#   'is_closed': False,
#   'last_name': 'Personal',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 262,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 263,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 264,
#   'is_closed': False,
#   'last_name': 'Пугачёва',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 265,
#   'is_closed': False,
#   'last_name': 'Истомин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Роман',
#   'id': 266,
#   'is_closed': False,
#   'last_name': 'Захаров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Наталья',
#   'id': 267,
#   'is_closed': True,
#   'last_name': 'Бердникова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Леонид',
#   'id': 268,
#   'is_closed': True,
#   'last_name': 'Ананьев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 269,
#   'is_closed': False,
#   'last_name': 'Миненок',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ирина',
#   'id': 270,
#   'is_closed': True,
#   'last_name': 'Рыбакова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Александр',
#   'id': 271,
#   'is_closed': True,
#   'last_name': 'Селиванов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Pavel',
#   'id': 272,
#   'is_closed': True,
#   'last_name': 'Morzhov',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Павел',
#   'id': 273,
#   'is_closed': True,
#   'last_name': 'Самойлов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 274,
#   'is_closed': False,
#   'last_name': 'Тюрина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 275,
#   'is_closed': True,
#   'last_name': 'Михайлова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Катарина',
#   'id': 276,
#   'is_closed': False,
#   'last_name': 'Коровникова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Александр',
#   'id': 277,
#   'is_closed': False,
#   'last_name': 'Кузнецов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 278,
#   'is_closed': True,
#   'last_name': 'Грей',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Катя',
#   'id': 279,
#   'is_closed': True,
#   'last_name': 'Розенберг',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Вера',
#   'id': 280,
#   'is_closed': True,
#   'last_name': 'Семенова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 281,
#   'is_closed': True,
#   'last_name': 'Иванова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 282,
#   'is_closed': False,
#   'last_name': 'Цимберг',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Елена',
#   'id': 283,
#   'is_closed': False,
#   'last_name': 'Андриенко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Александр',
#   'id': 284,
#   'is_closed': False,
#   'last_name': 'Кузнецов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 285,
#   'is_closed': True,
#   'last_name': 'Столовицкая',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Маргарита',
#   'id': 286,
#   'is_closed': False,
#   'last_name': 'Дмитриева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Иван',
#   'id': 287,
#   'is_closed': False,
#   'last_name': 'Кондаков',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Серго',
#   'id': 288,
#   'is_closed': True,
#   'last_name': 'Ваанпмлпва',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юлик',
#   'id': 289,
#   'is_closed': False,
#   'last_name': 'Суртаева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Аркадий',
#   'id': 290,
#   'is_closed': True,
#   'last_name': 'Гуманюк',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Виктор',
#   'id': 291,
#   'is_closed': True,
#   'last_name': 'Танчак',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 292,
#   'is_closed': False,
#   'last_name': 'Чупира',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 293,
#   'is_closed': True,
#   'last_name': 'Жеребкова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Татьяна',
#   'id': 294,
#   'is_closed': False,
#   'last_name': 'Учагина-Василенок',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Olga',
#   'id': 295,
#   'is_closed': True,
#   'last_name': 'Sergeecheva',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 296,
#   'is_closed': False,
#   'last_name': 'Вязьменская',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 297,
#   'is_closed': False,
#   'last_name': 'Сюткин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Евгений',
#   'id': 298,
#   'is_closed': False,
#   'last_name': 'Скоробогатько',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 299,
#   'is_closed': True,
#   'last_name': 'Вишневская',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юрий',
#   'id': 300,
#   'is_closed': False,
#   'last_name': 'Новичков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 301,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Павел',
#   'id': 302,
#   'is_closed': True,
#   'last_name': 'Биргер',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Оксана',
#   'id': 303,
#   'is_closed': False,
#   'last_name': 'Ласкателева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 304,
#   'is_closed': False,
#   'last_name': 'Малашевская',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Павел',
#   'id': 305,
#   'is_closed': True,
#   'last_name': 'Логачев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 306,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Стаська',
#   'id': 307,
#   'is_closed': True,
#   'last_name': 'Титова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 308,
#   'is_closed': False,
#   'last_name': 'Степанов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Ilya',
#   'id': 309,
#   'is_closed': True,
#   'last_name': 'Krivonogov',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Константин',
#   'id': 310,
#   'is_closed': False,
#   'last_name': 'Иванов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 311,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Кузьма',
#   'id': 312,
#   'is_closed': True,
#   'last_name': 'Кукушкин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Виталий',
#   'id': 313,
#   'is_closed': False,
#   'last_name': 'Шипов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 314,
#   'is_closed': False,
#   'last_name': 'Прядченко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Павел',
#   'id': 315,
#   'is_closed': False,
#   'last_name': 'Медведев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дарья',
#   'id': 316,
#   'is_closed': False,
#   'last_name': 'Лесохина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 317,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Надежда',
#   'id': 318,
#   'is_closed': False,
#   'last_name': 'Сомкина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Софья',
#   'id': 319,
#   'is_closed': False,
#   'last_name': 'Астраханцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Марина',
#   'id': 320,
#   'is_closed': False,
#   'last_name': 'Цветкова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анна',
#   'id': 321,
#   'is_closed': False,
#   'last_name': 'Гершон',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Евгений',
#   'id': 322,
#   'is_closed': True,
#   'last_name': 'Соколенко',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 323,
#   'is_closed': True,
#   'last_name': 'Орлов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Анастасия',
#   'id': 324,
#   'is_closed': True,
#   'last_name': 'Логинова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 325,
#   'is_closed': False,
#   'last_name': 'Желтов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 326,
#   'is_closed': False,
#   'last_name': 'Яроцкая',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 327,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Аня',
#   'id': 328,
#   'is_closed': False,
#   'last_name': 'Левина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 329,
#   'is_closed': True,
#   'last_name': 'Гончаренко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 330,
#   'is_closed': False,
#   'last_name': 'Чернецкий',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Эмиль',
#   'id': 331,
#   'is_closed': False,
#   'last_name': 'Байбагышев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Дима',
#   'id': 332,
#   'is_closed': False,
#   'last_name': 'Зеленцов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Агент Поддержки',
#   'id': 333,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Полина',
#   'id': 334,
#   'is_closed': False,
#   'last_name': 'Богуш',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Дмитрий',
#   'id': 335,
#   'is_closed': False,
#   'last_name': 'Овчиннов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 336,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 337,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 338,
#   'is_closed': False,
#   'last_name': 'Власов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Виктор',
#   'id': 339,
#   'is_closed': False,
#   'last_name': 'Вавилов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Oksana',
#   'id': 340,
#   'is_closed': False,
#   'last_name': 'Fimina',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Shmavon',
#   'id': 341,
#   'is_closed': True,
#   'last_name': 'Gazanchyan',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Dmitry',
#   'id': 342,
#   'is_closed': True,
#   'last_name': 'Svetloff',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 343,
#   'is_closed': False,
#   'last_name': 'Пилин',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Сергей',
#   'id': 344,
#   'is_closed': True,
#   'last_name': 'Фоминых',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Дарья',
#   'id': 345,
#   'is_closed': True,
#   'last_name': 'Фролова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Полина',
#   'id': 346,
#   'is_closed': False,
#   'last_name': 'Маркина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'id': 347,
#   'is_closed': False,
#   'last_name': 'Бойко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Галина',
#   'id': 348,
#   'is_closed': False,
#   'last_name': 'Румянцева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Анастасия',
#   'id': 349,
#   'is_closed': False,
#   'last_name': 'Силюкова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Павел',
#   'id': 350,
#   'is_closed': False,
#   'last_name': 'Таразевич',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Елена',
#   'id': 351,
#   'is_closed': True,
#   'last_name': 'Харламова',
#   'sex': 1},
#  {'can_access_closed': True,
# ...
#   'is_closed': False,
#   'last_name': 'Славов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 385,
#   'is_closed': True,
#   'last_name': 'Богданов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Надежда',
#   'id': 386,
#   'is_closed': False,
#   'last_name': 'Супрычева',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Наталья',
#   'id': 387,
#   'is_closed': True,
#   'last_name': 'Белая',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Валентин',
#   'id': 388,
#   'is_closed': False,
#   'last_name': 'Бурцев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 389,
#   'is_closed': False,
#   'last_name': 'Кочнев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 390,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 391,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 392,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 393,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Vlasta',
#   'id': 394,
#   'is_closed': False,
#   'last_name': 'Solovyeva',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Андрей',
#   'id': 395,
#   'is_closed': True,
#   'last_name': 'Титов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Olga',
#   'id': 396,
#   'is_closed': False,
#   'last_name': 'Dashkevich',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Marina',
#   'id': 397,
#   'is_closed': False,
#   'last_name': 'Slo',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Денис',
#   'id': 398,
#   'is_closed': False,
#   'last_name': 'Щукин',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 399,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 400,
#   'is_closed': False,
#   'last_name': 'Давыденко',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 401,
#   'is_closed': False,
#   'last_name': 'Поляк',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 402,
#   'is_closed': False,
#   'last_name': 'Королев',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Вера',
#   'id': 403,
#   'is_closed': True,
#   'last_name': 'Веткина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Эдуард',
#   'id': 404,
#   'is_closed': False,
#   'last_name': 'Николаев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 405,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Ольга',
#   'id': 406,
#   'is_closed': False,
#   'last_name': 'Тарасова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 407,
#   'is_closed': True,
#   'last_name': 'Же',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ирина',
#   'id': 408,
#   'is_closed': False,
#   'last_name': 'Белова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Виктория',
#   'id': 409,
#   'is_closed': True,
#   'last_name': 'Якунчикова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Alexander',
#   'id': 410,
#   'is_closed': True,
#   'last_name': 'Obl',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Нина',
#   'id': 411,
#   'is_closed': True,
#   'last_name': 'Отмас',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 412,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 413,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 414,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 415,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 416,
#   'is_closed': False,
#   'last_name': 'Жаржавская',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 417,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 418,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ярослав',
#   'id': 419,
#   'is_closed': True,
#   'last_name': 'Воронцов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Мария',
#   'id': 420,
#   'is_closed': False,
#   'last_name': 'Телегина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 421,
#   'is_closed': False,
#   'last_name': 'Щёголева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 422,
#   'is_closed': False,
#   'last_name': 'Соколов',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Тимур',
#   'id': 423,
#   'is_closed': True,
#   'last_name': 'Кармов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 424,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Анна',
#   'id': 425,
#   'is_closed': False,
#   'last_name': 'Войтенко',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 426,
#   'is_closed': True,
#   'last_name': 'Коновалова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алена',
#   'id': 427,
#   'is_closed': False,
#   'last_name': 'Матвейчук',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Александр',
#   'id': 428,
#   'is_closed': True,
#   'last_name': 'Кирпичников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Михаил',
#   'id': 429,
#   'is_closed': False,
#   'last_name': 'Зубков',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Piotr',
#   'id': 430,
#   'is_closed': False,
#   'last_name': 'Gr',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Мария',
#   'id': 431,
#   'is_closed': True,
#   'last_name': 'Ажинова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Ný',
#   'id': 432,
#   'is_closed': True,
#   'last_name': 'Lero',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Анастасия',
#   'id': 433,
#   'is_closed': False,
#   'last_name': 'Мальмрус',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 434,
#   'is_closed': False,
#   'last_name': 'Золотонос',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Константин',
#   'id': 435,
#   'is_closed': False,
#   'last_name': 'Паблопикассович',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Сергей',
#   'id': 436,
#   'is_closed': False,
#   'last_name': 'Дюжев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 437,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 438,
#   'is_closed': False,
#   'last_name': 'Шипилов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Тимофей',
#   'id': 439,
#   'is_closed': False,
#   'last_name': 'Стороженко',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Anastasia',
#   'id': 440,
#   'is_closed': False,
#   'last_name': 'Balashova',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 441,
#   'is_closed': False,
#   'last_name': 'Нигматуллина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 442,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Алексей',
#   'id': 443,
#   'is_closed': True,
#   'last_name': 'Юрецкий',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Алиса',
#   'id': 444,
#   'is_closed': False,
#   'last_name': 'Иванова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Филипп',
#   'id': 445,
#   'is_closed': False,
#   'last_name': 'Рамбов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 446,
#   'is_closed': False,
#   'last_name': 'Богданов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Marianna',
#   'id': 447,
#   'is_closed': False,
#   'last_name': 'Demenkova',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Никита',
#   'id': 448,
#   'is_closed': False,
#   'last_name': 'Аникеев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 449,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Марина',
#   'id': 450,
#   'is_closed': False,
#   'last_name': 'Требина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 451,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Олег',
#   'id': 452,
#   'is_closed': False,
#   'last_name': 'Желтянников',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Ярославна',
#   'id': 453,
#   'is_closed': False,
#   'last_name': 'Гаген-Торн',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Андрей',
#   'id': 454,
#   'is_closed': False,
#   'last_name': 'Гук',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Евгений',
#   'id': 455,
#   'is_closed': True,
#   'last_name': 'Шехтер',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 456,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Владимир',
#   'id': 457,
#   'is_closed': False,
#   'last_name': 'Баранов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Сергей',
#   'id': 458,
#   'is_closed': False,
#   'last_name': 'Нагапетян',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 459,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Ilya',
#   'id': 460,
#   'is_closed': False,
#   'last_name': 'Dneprovsky',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 461,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 462,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Людмила',
#   'id': 463,
#   'is_closed': False,
#   'last_name': 'Захарова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 464,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 465,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Anastasia',
#   'id': 466,
#   'is_closed': False,
#   'last_name': 'Mikhaylova',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Игорь',
#   'id': 467,
#   'is_closed': True,
#   'last_name': 'Перекопский',
#   'sex': 2},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Паша',
#   'id': 468,
#   'is_closed': False,
#   'last_name': 'Кипелов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Екатерина',
#   'id': 469,
#   'is_closed': False,
#   'last_name': 'Пушкина',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Антон',
#   'id': 470,
#   'is_closed': False,
#   'last_name': 'Зайцев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дмитрий',
#   'id': 471,
#   'is_closed': False,
#   'last_name': 'Никончук',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Евгения',
#   'id': 472,
#   'is_closed': False,
#   'last_name': 'Захарова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алёна',
#   'id': 473,
#   'is_closed': False,
#   'last_name': 'Тайлер',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 474,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 475,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': False,
#   'first_name': 'Лена',
#   'id': 476,
#   'is_closed': True,
#   'last_name': 'Самуйлова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Алексей',
#   'id': 477,
#   'is_closed': False,
#   'last_name': 'Комаров',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Кирилл',
#   'id': 478,
#   'is_closed': True,
#   'last_name': 'Мошков',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Виктория',
#   'id': 479,
#   'is_closed': True,
#   'last_name': 'Стацевич',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Yarik',
#   'id': 480,
#   'is_closed': True,
#   'last_name': 'Markov',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Софья',
#   'id': 481,
#   'is_closed': False,
#   'last_name': 'Чебанова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 482,
#   'is_closed': False,
#   'last_name': 'Васильева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 483,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Юлия',
#   'id': 484,
#   'is_closed': False,
#   'last_name': 'Нураева',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'banned',
#   'first_name': 'Дарья',
#   'id': 485,
#   'is_closed': False,
#   'last_name': 'Павлова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Наталия',
#   'id': 486,
#   'is_closed': True,
#   'last_name': 'Шабанова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 487,
#   'is_closed': True,
#   'last_name': 'Каткова',
#   'sex': 1},
#  {'can_access_closed': True,
#   'first_name': 'Алексей',
#   'id': 488,
#   'is_closed': False,
#   'last_name': 'Леонидович',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Александра',
#   'id': 489,
#   'is_closed': True,
#   'last_name': 'Родионова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 490,
#   'is_closed': True,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 491,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Кирилл',
#   'id': 492,
#   'is_closed': False,
#   'last_name': 'Ширяев',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Дарья',
#   'id': 493,
#   'is_closed': False,
#   'last_name': 'Монихарт',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Анна',
#   'id': 494,
#   'is_closed': True,
#   'last_name': 'Бабурова',
#   'sex': 1},
#  {'can_access_closed': False,
#   'first_name': 'Михаил',
#   'id': 495,
#   'is_closed': True,
#   'last_name': 'Кадобнов',
#   'sex': 2},
#  {'can_access_closed': True,
#   'first_name': 'Григорий',
#   'id': 496,
#   'is_closed': False,
#   'last_name': 'Малыгин',
#   'sex': 2},
#  {'can_access_closed': False,
#   'first_name': 'Светлана',
#   'id': 497,
#   'is_closed': True,
#   'last_name': 'Лапина',
#   'sex': 1},
#  {'can_access_closed': False,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 498,
#   'is_closed': True,
#   'last_name': '',
#   'sex': 1},
#  {'can_access_closed': True,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'id': 499,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 0},
#  {'can_access_closed': True,
#   'first_name': 'Анонимный пользователь',
#   'id': 500,
#   'is_closed': False,
#   'last_name': '',
#   'sex': 2}]
# 0.48578199052132703

# %% [markdown]
# ## Сбор информации из групп

# %% [markdown]
# Теперь мы научимся считать произвольные метрики групп, собирая данные из API и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# - ограничение на количество вызовов в единицу времени;
# - ограничение на количество выгружаемых строк за один запрос.
#
# Ограничение на количество запросов в единицу времени сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчётов можно выгрузить и уложиться в действующий лимит.
#
# Однако второе ограничение не удастся обойти в случае выгрузки больших отчётов. Например, чтобы получить список всех пользователей популярной группы, серверу, возможно, придётся отправить ответ, содержащий миллионы записей.

# %% [markdown]
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk социальной сети ВКонтакте.
#
# Обратимся к документации, чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод groups.getMembers.
#
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %% [markdown]
# ### Ограничение на клличество данных

# %%
import requests # Импортируем модуль requests
token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': VKONTAKTE_SERVICED_API_KEY} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13693259, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 832, 834, 847, 900, 905, 907, 914, 930, 943, 952, 958, 966, 976, 997, 1000, 1018, 1023, 1032, 1033, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1273, 1301, 1333, 1334, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2513, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2909, 2919, 2922, 2932, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 3994, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4157, 4169, 4189, 4192, 4236, 4262, 4282, 4326, 4378, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4790, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5073, 5161, 5166, 5183, 5251, 5262, 5273, 5276, 5280, 5286, 5354, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5484, 5527, 5546, 5547, 5585, 5590, 5597, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5968, 5990, 5991, 5993, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6240, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6440, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6960, 6994, 7012, 7040, 7047, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7126, 7141, 7188, 7200, 7226, 7227, 7286, 7290, 7338, 7360, 7402, 7404, 7408, 7428, 7451, 7481, 7488, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7652, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8069, 8080, 8093, 8149, 8151, 8156, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8485, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8909, 8910, 8937, 8959, 9000, 9014, 9016, 9018, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9343, 9352, 9399, 9408, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9598, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9925, 9954, 9971, 9981, 9993, 10090, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10621, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11420, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 11986, 12005, 12029, 12036, 12097, 12133, 12150, 12154, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12597, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 127 ...

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550]

# %%
import requests # Импортируем модуль requests
token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': VKONTAKTE_SERVICED_API_KEY} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550]

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# ### Ограничение по частоте запросов

# %% [markdown]
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': VKONTAKTE_SERVICED_API_KEY} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ## Лайки, репосты и комментарии

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': VKONTAKTE_SERVICED_API_KEY, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 772,
#               'items': [{'attachments': [{'photo': {'access_key': '519d82b98a13833f40',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353619,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340',
#                                                                'width': 510},
#                                                               {'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50',
#                                                                'width': 75},
#                                                               {'height': 1707,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707',
#                                                                'width': 2560},
#                                                               {'height': 403,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403',
#                                                                'width': 604},
#                                                               {'height': 538,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538',
#                                                                'width': 807},
#                                                               {'height': 853,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '8a3e2453fc16be1bb6'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '51aec1e439b61e73f7',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353620,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340',
#                                                                'width': 510},
#                                                               {'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50',
#                                                                'width': 75},
#                                                               {'height': 1707,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707',
#                                                                'width': 2560},
#                                                               {'height': 403,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403',
#                                                                'width': 604},
#                                                               {'height': 538,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538',
#                                                                'width': 807},
#                                                               {'height': 853,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '69146fb39a274d472a'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': 'abf6629c9dcecf38c9',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353621,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340',
#                                                                'width': 510},
#                                                               {'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50',
#                                                                'width': 75},
#                                                               {'height': 1707,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707',
#                                                                'width': 2560},
#                                                               {'height': 403,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403',
#                                                                'width': 604},
#                                                               {'height': 538,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538',
#                                                                'width': 807},
#                                                               {'height': 853,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '0af5949c92331c6c3d'},
#                                           'type': 'photo'},
#                                          {'link': {'description': 'Дом '
#                                                                   'талантливых '
#                                                                   'клиперов-капибар '
#                                                                   'от VK '
#                                                                   'Клипов и '
#                                                                   'Московского '
#                                                                   'зоопарка',
#                                                    'target': 'internal',
#                                                    'title': 'Добро пожаловать '
#                                                             'в Капихаус!',
#                                                    'url': 'http://clips.vk.com/special/capy_house'},
#                                           'type': 'link'}],
#                          'comments': {'count': 1751},
#                          'date': 1730375700,
#                          'from_id': -22822305,
#                          'hash': 'BXUFVO5iK8y0kt32bQ',
#                          'id': 1521255,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 3227,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 568},
#                          'text': 'Спешим поделиться крайне милыми новостями: '
#                                  'VK Клипы стали официальным опекуном '
#                                  'семейства капибар в Московском зоопарке. Вы '
#                                  'только посмотрите на этих мемных красавцев!\n'
#                                  '\n'
#                                  'Милахи получили годовой запас питания и '
#                                  'подарки, которые сделают их жизнь комфортнее '
#                                  'и безопаснее.\n'
#                                  '\n'
#                                  'Хотите увидеть ещё больше капибар (а кто не '
#                                  'хочет)? Заглядывайте к ним в «Капихаус»!\n'
#                                  '\n'
#                                  'Тут вы сможете посмотреть клипы с '
#                                  'капибарами, узнать интересные факты о них и '
#                                  'получить уникальные стикеры ВКонтакте: '
#                                  'clips.vk.com/special/capy_house',
#                          'type': 'post',
#                          'views': {'count': 1655386}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'can_add': 0,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 1385,
#                                                     'date': 1728572600,
#                                                     'description': 'Продолжаем '
#                                                                    'принимать '
#                                                                    'поздравления '
#                                                                    'по случаю '
#                                                                    'нашего '
#                                                                    'совершеннолетия '
#                                                                    '🎉\n'
#                                                                    '\n'
#                                                                    'Спасибо '
#                                                                    'всем за '
#                                                                    'тёплые '
#                                                                    'слова!',
#                                                     'duration': 64,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=0&type=39&tkn=vKplsIwbCsYi8HlTDy3xpeAvB5I&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=0&type=39&tkn=vKplsIwbCsYi8HlTDy3xpeAvB5I&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=0&type=39&tkn=vKplsIwbCsYi8HlTDy3xpeAvB5I&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=0&type=39&tkn=vKplsIwbCsYi8HlTDy3xpeAvB5I&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=0&type=39&tkn=vKplsIwbCsYi8HlTDy3xpeAvB5I&fn=vid_f',
#                                                     'height': 1920,
#                                                     'id': 456242856,
#                                                     'local_views': 430575,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=15&type=39&tkn=iiZb83d9okPCOr6v-16bpEosOhI&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=15&type=39&tkn=iiZb83d9okPCOr6v-16bpEosOhI&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=15&type=39&tkn=iiZb83d9okPCOr6v-16bpEosOhI&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=7029659536035&idx=15&type=39&tkn=iiZb83d9okPCOr6v-16bpEosOhI&fn=vid_x',
#                                                     'repeat': 1,
#                                                     'response_type': 'full',
#                                                     'should_stretch': False,
#                                                     'title': 'Clip by @vk',
#                                                     'track_code': 'video_ba8addc9zGVDmLjR-JeZbaTk0Apv04kSfO3ciyckfUiy3W6vIHniRFySuNv5lZ8CoI7VB27ViCBE2OqPUEURL2E4qiRIaM92bqqK6cqlql2RRBvAph5C37sn6w',
#                                                     'views': 430575,
#                                                     'wall_post_id': 1518745,
#                                                     'width': 1080}}],
#                          'comments': {'count': 1389},
#                          'date': 1728573014,
#                          'from_id': -22822305,
#                          'hash': 'F7JtGPN31o39gzLTdQ',
#                          'id': 1518745,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 2233,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 200},
#                          'text': '',
#                          'type': 'post',
#                          'views': {'count': 575279}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '8973b3ed07c6722abe',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 587,
#                                                     'date': 1728560742,
#                                                     'description': '',
#                                                     'duration': 21,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=0&type=39&tkn=WN548oR5nW5jY5HXuzhjkcXDLxc&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=0&type=39&tkn=WN548oR5nW5jY5HXuzhjkcXDLxc&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=0&type=39&tkn=WN548oR5nW5jY5HXuzhjkcXDLxc&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=0&type=39&tkn=WN548oR5nW5jY5HXuzhjkcXDLxc&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=0&type=39&tkn=WN548oR5nW5jY5HXuzhjkcXDLxc&fn=vid_f',
#                                                     'height': 2160,
#                                                     'id': 456242852,
#                                                     'local_views': 254294,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=3&type=39&tkn=EwOneijS4le_4wH6CbaB4OmJqm0&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=3&type=39&tkn=EwOneijS4le_4wH6CbaB4OmJqm0&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=3&type=39&tkn=EwOneijS4le_4wH6CbaB4OmJqm0&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=7144125041382&idx=3&type=39&tkn=EwOneijS4le_4wH6CbaB4OmJqm0&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'should_stretch': False,
#                                                     'title': 'Video by '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_6e109b76E5D_G_WGRwW9gjMYgOCENG16sKqYz1Yg6vX8u_HC4jkiseEZ8uFEAr-KM3SF1bIGWUiIn6rAIUGGmfyq3PDQARCD0tY4QYrIcU35uLU',
#                                                     'views': 254294,
#                                                     'width': 3840}}],
#                          'comments': {'count': 587},
#                          'date': 1728560919,
#                          'from_id': -22822305,
#                          'hash': '3VW_Hrenh9ktUtIyaA',
#                          'id': 1518531,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 1647,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 251},
#                          'text': 'Сегодня ВКонтакте исполнилось 18 лет, и мы '
#                                  'поздравляем всех, кто родился с нами в один '
#                                  'день!\n'
#                                  '\n'
#                                  'Если ваш день рождения тоже сегодня — '
#                                  'отмечайтесь в комментариях! Может, встретим '
#                                  'вас на билбордах в Москве или Питере 🎂',
#                          'type': 'post',
#                          'views': {'count': 367401}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'd79ee138379a60375a',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 443,
#                                                     'date': 1728310087,
#                                                     'description': '',
#                                                     'duration': 30,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=0&type=39&tkn=o9uwdUvCqqIyqoL8W4t0yq8zG1M&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=0&type=39&tkn=o9uwdUvCqqIyqoL8W4t0yq8zG1M&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=0&type=39&tkn=o9uwdUvCqqIyqoL8W4t0yq8zG1M&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=0&type=39&tkn=o9uwdUvCqqIyqoL8W4t0yq8zG1M&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=0&type=39&tkn=o9uwdUvCqqIyqoL8W4t0yq8zG1M&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456242851,
#                                                     'local_views': 234957,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=9&type=39&tkn=J8gnGDPEa-SSku1T8BDXto3T3ag&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=9&type=39&tkn=J8gnGDPEa-SSku1T8BDXto3T3ag&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=9&type=39&tkn=J8gnGDPEa-SSku1T8BDXto3T3ag&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=7190896118473&idx=9&type=39&tkn=J8gnGDPEa-SSku1T8BDXto3T3ag&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'should_stretch': False,
#                                                     'title': 'Video by '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_521ca99dVXGKRSUWzOjo3QLoT_qfrTgvcM-Yo3yTVWzrhL6wR5pkUJRHInHP7-rVB4VPz6mfDB1I-qmsC_I5AOuVk4J1olZip4jo0QElJBLISHo',
#                                                     'views': 234957,
#                                                     'width': 1920}}],
#                          'comments': {'count': 452},
#                          'date': 1728310195,
#                          'from_id': -22822305,
#                          'hash': 'zlR_fPtyEV-fidhcXw',
#                          'id': 1518024,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 719,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 174},
#                          'text': 'VK Музыка обновилась! Что нового?\n'
#                                  '\n'
#                                  'Обновлённый VK Микс теперь предлагает музыку '
#                                  'на любой вкус. Выбирайте настроение, '
#                                  'узнаваемость трека и язык — алгоритм быстро '
#                                  'подстроится под вас.\n'
#                                  '\n'
#                                  'Главная страница стала удобнее: одним '
#                                  'движением переключайтесь между '
#                                  'рекомендациями и любимыми треками из вашей '
#                                  'коллекции.\n'
#                                  '\n'
#                                  'Плеер стал функциональнее, а в «Моей музыке» '
#                                  'теперь можно скачать все треки одним '
#                                  'нажатием.\n'
#                                  '\n'
#                                  'И немного волшебства — фича с гироскопом. '
#                                  'Попробуйте повернуть телефон на главном '
#                                  'экране VK Музыки и посмотрите, что '
#                                  'произойдёт.\n'
#                                  '\n'
#                                  'Всё это уже доступно в приложениях ВКонтакте '
#                                  'и VK Музыки. Открывайте и создавайте своё '
#                                  'музыкальное настроение!',
#                          'type': 'post',
#                          'views': {'count': 335768}},
#                         {'attachments': [{'photo': {'access_key': 'd7f81679d39242af9f',
#                                                     'album_id': -7,
#                                                     'date': 1727082847,
#                                                     'id': 457352967,
#                                                     'orig_photo': {'height': 2560,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1516443,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=1280x1280',
#                                                                'width': 1280},
#                                                               {'height': 2560,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=2560x2560',
#                                                                'width': 2560},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-11.userapi.com/s/v1/ig2/z-MuQO23NiAk8OyRBmV2azx43AaopWfUsrt9HpukcxoTRKXPhsI9PLj_zzzo1bqyXZxEesDcX82GQiRAkhEsXSYM.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2560x2560&from=bu&cs=510x510',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'd8fd397cde9175745a'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 820},
#                          'date': 1727083149,
#                          'from_id': -22822305,
#                          'hash': 'B0rEtiXaicK-rkvSZQ',
#                          'id': 1516443,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 866,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 291},
#                          'text': 'Новая программа монетизации от VK Видео: '
#                                  'авторы смогут зарабатывать больше на своём '
#                                  'контенте. \n'
#                                  '\n'
#                                  'Новая программа монетизации будет работать '
#                                  'по модели Revenue Share: авторы получат от '
#                                  '50 до 80% дохода от показов рекламы в их '
#                                  'видео. Главные условия — оригинальность и '
#                                  'длительность (дольше 2 минут) роликов. \n'
# ...
#                                                                    'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1453386,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-9.userapi.com/s/v1/ig2/c_kKQqwiw6VFNVR3brpHWzUIh3Kyv5pJfxMRD9NlxjhOjThenoJ7FsgScioIo_Q_RxbFOV7IqO442Spla04cj3W0.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '3655bc2ec44cd38cef'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 182},
#                          'date': 1705042801,
#                          'from_id': -22822305,
#                          'hash': '_d6GL7CD19iOoJMgTg',
#                          'id': 1453386,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 848,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 249},
#                          'text': 'А вы знали, что ВКонтакте можно создавать '
#                                  'свои всплывающие подсказки для стикеров?\n'
#                                  '\n'
#                                  'Очень удобная функция. Можно сделать так, '
#                                  'что при вводе фразы «январские праздники» '
#                                  'будет выскакивать стикер с весёлым Персиком, '
#                                  'а при слове «работа» — с грустным.\n'
#                                  '\n'
#                                  'Для этого нужно:\n'
#                                  '\n'
#                                  '• Перейти в этого '
#                                  '[vk.me/stickerskeywords|чат-бота].\n'
#                                  '• Скинуть ему слово, фразу или эмодзи.\n'
#                                  '• Выбрать, какой стикер будет предлагаться '
#                                  'при их вводе.\n'
#                                  '\n'
#                                  'Готово, пользуйтесь!',
#                          'type': 'post',
#                          'views': {'count': 482486}},
#                         {'attachments': [{'photo': {'access_key': 'a27db836029a08847d',
#                                                     'album_id': -7,
#                                                     'date': 1704798347,
#                                                     'id': 457346113,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1453149,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-4.userapi.com/s/v1/ig2/mtciQWiR6IFcwWS999iGwK6TSgE4eYF2H0Eexri3-t9gu7jB22OZmbddMnB7bTkJ5UpuyK_9l82lM5nQX2WPykyO.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '40fa1855069168eb30'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 176},
#                          'date': 1704873840,
#                          'from_id': -22822305,
#                          'hash': 'L9NhqJz5HNBRnpTBAg',
#                          'id': 1453149,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 746,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 283},
#                          'text': 'Крайне актуальный вопрос после праздников: '
#                                  'какие фотографии с отдыха можно безопасно '
#                                  'показывать всем, а какие лучше оставить для '
#                                  'себя?\n'
#                                  '\n'
#                                  'Ответим на него вместе с экспертом по '
#                                  'информационной безопасности VK Верой '
#                                  'Колениковой и звёздным спикером, '
#                                  'стендап-комиком Зоей Яровицыной!\n'
#                                  '\n'
#                                  'Кто может, приходите послушать лично 12 '
#                                  'января в 19:00 в Российскую государственную '
#                                  'библиотеку. Надо только зарегистрироваться: '
#                                  'vk.cc/ctL1tG.\n'
#                                  '\n'
#                                  'А трансляция мероприятия будет доступна '
#                                  '[vk.com/leninka_ru|здесь].',
#                          'type': 'post',
#                          'views': {'count': 423061}}]}}

# %%
len(response.json()['response']['items'])
# Out:
# 100

# %%
response.json()['response']['items'][0]
# Out:
# {'inner_type': 'wall_wallpost',
#  'comments': {'count': 1751},
#  'marked_as_ads': 0,
#  'hash': 'BXUFVO5iK8y0kt32bQ',
#  'type': 'post',
#  'push_subscription': {'is_subscribed': False},
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1730375201,
#     'id': 457353619,
#     'owner_id': -22822305,
#     'access_key': '519d82b98a13833f40',
#     'sizes': [{'height': 87,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87'},
#      {'height': 87,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87'},
#      {'height': 133,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133'},
#      {'height': 213,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213'},
#      {'height': 340,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340'},
#      {'height': 50,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50'},
#      {'height': 1707,
#       'type': 'w',
#       'width': 2560,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707'},
#      {'height': 403,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403'},
#      {'height': 538,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538'},
#      {'height': 853,
#       'type': 'z',
#       'width': 1280,
#       'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': '8a3e2453fc16be1bb6',
#     'orig_photo': {'height': 1707,
#      'type': 'base',
#      'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#      'width': 2560}}},
#   {'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1730375201,
#     'id': 457353620,
#     'owner_id': -22822305,
#     'access_key': '51aec1e439b61e73f7',
#     'sizes': [{'height': 87,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87'},
#      {'height': 87,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87'},
#      {'height': 133,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133'},
#      {'height': 213,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213'},
#      {'height': 340,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340'},
#      {'height': 50,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50'},
#      {'height': 1707,
#       'type': 'w',
#       'width': 2560,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707'},
#      {'height': 403,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403'},
#      {'height': 538,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538'},
#      {'height': 853,
#       'type': 'z',
#       'width': 1280,
#       'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': '69146fb39a274d472a',
#     'orig_photo': {'height': 1707,
#      'type': 'base',
#      'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#      'width': 2560}}},
#   {'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1730375201,
#     'id': 457353621,
#     'owner_id': -22822305,
#     'access_key': 'abf6629c9dcecf38c9',
#     'sizes': [{'height': 87,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87'},
#      {'height': 87,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87'},
#      {'height': 133,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133'},
#      {'height': 213,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213'},
#      {'height': 340,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340'},
#      {'height': 50,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50'},
#      {'height': 1707,
#       'type': 'w',
#       'width': 2560,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707'},
#      {'height': 403,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403'},
#      {'height': 538,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538'},
#      {'height': 853,
#       'type': 'z',
#       'width': 1280,
#       'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': '0af5949c92331c6c3d',
#     'orig_photo': {'height': 1707,
#      'type': 'base',
#      'url': 'https://sun9-36.userapi.com/s/v1/ig2/shru5tcULIR3ihxpxEZWnc8kxNN-MAYjQXb5dbLdfaXNzF-dxVGNUwlmHb_0J3FIz4-CTTrHDTiDqW8LLVxuynD8.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#      'width': 2560}}},
#   {'type': 'link',
#    'link': {'url': 'http://clips.vk.com/special/capy_house',
#     'description': 'Дом талантливых клиперов-капибар от VK Клипов и Московского зоопарка',
#     'title': 'Добро пожаловать в Капихаус!',
#     'target': 'internal'}}],
#  'date': 1730375700,
#  'from_id': -22822305,
#  'id': 1521255,
#  'likes': {'can_like': 0, 'count': 3227, 'user_likes': 0},
#  'owner_id': -22822305,
#  'post_type': 'post',
#  'reposts': {'count': 568},
#  'text': 'Спешим поделиться крайне милыми новостями: VK Клипы стали официальным опекуном семейства капибар в Московском зоопарке. Вы только посмотрите на этих мемных красавцев!\n\nМилахи получили годовой запас питания и подарки, которые сделают их жизнь комфортнее и безопаснее.\n\nХотите увидеть ещё больше капибар (а кто не хочет)? Заглядывайте к ним в «Капихаус»!\n\nТут вы сможете посмотреть клипы с капибарами, узнать интересные факты о них и получить уникальные стикеры ВКонтакте: clips.vk.com/special/capy_house',
#  'views': {'count': 1655386}}

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'VK Музыка обновилась! Что ново': [452, 719, 174, 1728310195],
#  'Какие персонажи — такие и их л': [592, 1201, 184, 1726227240],
#  'Кто знает, какой сегодня день ': [307, 884, 92, 1725376800],
#  'Негласное правило ВКонтакте № ': [357, 961, 180, 1726056001],
#  'Новая программа монетизации от': [820, 866, 291, 1727083149],
#  'Обновился VK Мессенджер в веб-': [468, 759, 300, 1726748100],
#  'Представляем VK AdBlogger — но': [161, 424, 158, 1726654200],
#  'Сегодня ВКонтакте исполнилось ': [587, 1647, 251, 1728560919],
#  'Спешим поделиться крайне милым': [1751, 3227, 568, 1730375700],
#  'Что можно успеть за 60 секунд?': [433, 1696, 157, 1726757657]}

# %% [markdown]
# # 7. Как настроить регулярную выгрузку данных

# %% [markdown]
# ## Как настроить автоматический запуск

# %% [markdown]
# Исполняемый по расписанию код часто называют задачей (англ. task). Для планирования задач в Python есть несколько библиотек, среди которых — популярный и простой в использовании модуль **schedule** (c англ. расписание). Он позволяет запускать код как с определённым интервалом, так и в заданное время.
#
# Модуль **schedule** не входит в стандартную библиотеку Python, поэтому его необходимо установить:

# %%
import schedule # Импортируем модуль schedule

# %%
def task(): 
    print('Hello! I am a task!') 
    return

# %% [markdown]
# ## Выполнение функции

# %% [markdown]
# После того как мы создали нашу функцию и определились со временем её запуска, мы можем запустить наш менеджер расписания (schedule). Для этого надо создать бесконечный цикл. Да-да, именно так, ведь скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод run_pending() для объекта schedule, который будет проверять, нет ли задачи, которую пора выполнить.
#
# После вызова метода run_pending() нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Давайте напишем этот код.
#
# Для создания паузы мы будем использовать метод sleep из модуля time, поэтому наш код начнётся с импорта данного модуля

# %% [markdown]
# import time
# while True:
#     schedule.run_pending()
#     time.sleep(1)

# %%
import schedule

def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(5).seconds.do(task)

import time 
while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Hello! I am a task!
# Hello! I am a task!
# Hello! I am a task!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 12
#      10 while True:
#      11     schedule.run_pending()
# ---> 12     time.sleep(1)
#
# KeyboardInterrupt:

# %%
def star_triangle(r):
   for x in range(r):
      print(' '*(r-x-1)+'*'*(2*x+1))

star_triangle(7)
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************
